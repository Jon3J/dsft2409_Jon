# %% [markdown]
#    #                                                  Titanic Exercise
#
#    ![titanic](https://userscontent2.emaze.com/images/a5f68f37-6349-4065-a1fc-921cbe7401b2/958230111417e36d6b3c67ffd7bc3494.jpeg)
#    #### Practise Pandas

# %% [markdown]
# First of all, import the needed libraries.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1. Read in filename and call the variable `titanic`
#     - Explore the `titanic` dataset using `info`, `dtypes` & `describe`

# %%
titanic = pd.read_csv("data/titanic.csv")
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
titanic.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
titanic.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %% [markdown]
# 2. Create a separate dataframe with the columns `['name', 'sex', 'age']`, call it `people`
#
# It can be done two ways, do it both!

# %%
people = titanic[['name', 'sex', 'age']]
people
# Out:
#                                                  name     sex    age
# 0                       Allen, Miss. Elisabeth Walton  female  29.00
# 1                      Allison, Master. Hudson Trevor    male   0.92
# 2                        Allison, Miss. Helen Loraine  female   2.00
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.50
# 1307                              Zakarian, Mr. Ortin    male  27.00
# 1308                               Zimmerman, Mr. Leo    male  29.00
#
# [1309 rows x 3 columns]

# %%
people = pd.DataFrame({
    'name': titanic['name'],
    'style': titanic['sex'],
    'abv': titanic['age']
})

people
# Out:
#                                                  name   style    abv
# 0                       Allen, Miss. Elisabeth Walton  female  29.00
# 1                      Allison, Master. Hudson Trevor    male   0.92
# 2                        Allison, Miss. Helen Loraine  female   2.00
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.50
# 1307                              Zakarian, Mr. Ortin    male  27.00
# 1308                               Zimmerman, Mr. Leo    male  29.00
#
# [1309 rows x 3 columns]

# %% [markdown]
# 3. Print the output of `people` showing the first three rows and the last four rows, using `append`,`tail` and `head`

# %%
primeras_filas = people.head(3)
primeras_filas
# Out:
#                              name   style    abv
# 0   Allen, Miss. Elisabeth Walton  female  29.00
# 1  Allison, Master. Hudson Trevor    male   0.92
# 2    Allison, Miss. Helen Loraine  female   2.00

# %%
ultimas_filas = people.tail(4)
ultimas_filas
# Out:
#                            name   style   abv
# 1305      Zabour, Miss. Thamine  female   NaN
# 1306  Zakarian, Mr. Mapriededer    male  26.5
# 1307        Zakarian, Mr. Ortin    male  27.0
# 1308         Zimmerman, Mr. Leo    male  29.0

# %%
resultado = pd.concat([primeras_filas, ultimas_filas])
resultado
# Out:
#                                 name   style    abv
# 0      Allen, Miss. Elisabeth Walton  female  29.00
# 1     Allison, Master. Hudson Trevor    male   0.92
# 2       Allison, Miss. Helen Loraine  female   2.00
# 1305           Zabour, Miss. Thamine  female    NaN
# 1306       Zakarian, Mr. Mapriededer    male  26.50
# 1307             Zakarian, Mr. Ortin    male  27.00
# 1308              Zimmerman, Mr. Leo    male  29.00

# %%
#No me dejaba hacer un .append() con el dataframe (deprecated)

# %% [markdown]
# 4. Slice the row from 3 to 9, call it `s_titanic`

# %%
s_titanic = people.iloc[3:10]
s_titanic
# Out:
#                                               name   style   abv
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.0
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0
# 5                              Anderson, Mr. Harry    male  48.0
# 6                Andrews, Miss. Kornelia Theodosia  female  63.0
# 7                           Andrews, Mr. Thomas Jr    male  39.0
# 8    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0
# 9                          Artagaveytia, Mr. Ramon    male  71.0

# %% [markdown]
# 5. Slice the row from 40 to 63 in reverse order, call it `s_titanic_rev`

# %%
s_titanic_rev = people.iloc[63:39:-1]
s_titanic_rev
# Out:
#                                                  name   style   abv
# 63  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0
# 62                        Chaffee, Mr. Herbert Fuller    male  46.0
# 61  Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0
# 60                      Cavendish, Mr. Tyrell William    male  36.0
# 59  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...  female   NaN
# 58                             Case, Mr. Howard Brown    male  49.0
# 57          Carter, Mrs. William Ernest (Lucile Polk)  female  36.0
# 56                         Carter, Mr. William Ernest    male  36.0
# 55                          Carter, Miss. Lucile Polk  female  14.0
# 54                Carter, Master. William Thornton II    male  11.0
# 53                             Carrau, Mr. Jose Pedro    male  17.0
# 52                            Carrau, Mr. Francisco M    male  28.0
# 51                           Carlsson, Mr. Frans Olof    male  33.0
# ...

# %% [markdown]
# 6. Slice the columns from the starting column to `'parch'`, call it `left_columns`

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
left_columns = titanic.loc[:,:'parch']
left_columns
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch
# 0     female  29.00      0      0
# ...

# %% [markdown]
# 7. Slice the columns from `'name'` to `'age'`, call it `middle_columns`

# %%
middle_columns = titanic.loc[:,'name':'age']
middle_columns
# Out:
#                                                  name     sex    age
# 0                       Allen, Miss. Elisabeth Walton  female  29.00
# 1                      Allison, Master. Hudson Trevor    male   0.92
# 2                        Allison, Miss. Helen Loraine  female   2.00
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.50
# 1307                              Zakarian, Mr. Ortin    male  27.00
# 1308                               Zimmerman, Mr. Leo    male  29.00
#
# [1309 rows x 3 columns]

# %% [markdown]
# 8. Slice the columns from `'ticket'` to the end, call it `right_columns`

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
right_columns = titanic.loc[:,'ticket':]
right_columns
# Out:
#       ticket      fare    cabin embarked boat   body  \
# 0      24160  211.3375       B5        S    2    NaN
# 1     113781  151.5500  C22 C26        S   11    NaN
# 2     113781  151.5500  C22 C26        S  NaN    NaN
# 3     113781  151.5500  C22 C26        S  NaN  135.0
# 4     113781  151.5500  C22 C26        S  NaN    NaN
# ...      ...       ...      ...      ...  ...    ...
# 1304    2665   14.4542      NaN        C  NaN  328.0
# 1305    2665   14.4542      NaN        C  NaN    NaN
# 1306    2656    7.2250      NaN        C  NaN  304.0
# 1307    2670    7.2250      NaN        C  NaN    NaN
# 1308  315082    7.8750      NaN        S  NaN    NaN
#
#                             home.dest
# 0                        St Louis, MO
# 1     Montreal, PQ / Chesterville, ON
# 2     Montreal, PQ / Chesterville, ON
# 3     Montreal, PQ / Chesterville, ON
# 4     Montreal, PQ / Chesterville, ON
# ...                               ...
# 1304                              NaN
# ...

# %% [markdown]
# 9. What is the name of the oldest person who died in the Titanic? Was he or she travelling alone or had any family travelling with them?

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
muertes = titanic.loc[titanic['survived'] == 0]
edad = muertes.loc[muertes['age'].idxmax()]
nombre = edad['name']
print(f"La persona de mayor edad que murió en el Titanic fue: {nombre}")
# Out:
# La persona de mayor edad que murió en el Titanic fue: Svensson, Mr. Johan

# %% [markdown]
# In order to give an answer to the second question you should find out which columns give you that info. Usually part of your job as a Data Scientist will be get to know the dataset which you are working with. In this case the columns which give you that info are the following:
#         - 'sibsp' Number of Siblings/Spouses Aboard
#         - 'parch' Number of Parents/Children Aboard

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
muertes = titanic.loc[titanic['survived'] == 0]
persona_mas_anciana = muertes.loc[muertes['age'].idxmax()]
# Extraemos la información más relevante, es decir nombre, edad...
nombre = persona_mas_anciana['name']
age = persona_mas_anciana['age']
print(f"La persona más anciana que falleció en el Titanic fue {nombre}, con {age} años.")
# Out:
# La persona más anciana que falleció en el Titanic fue Svensson, Mr. Johan, con 74.0 años.

# %%
#Vamos a determinar si viajaba solo o con familia
sibsp = persona_mas_anciana['sibsp']
parch = persona_mas_anciana['parch']
viajando_solo = (sibsp == 0) and (parch == 0)
if viajando_solo:
    print("Esta persona viajaba sola.")
else:
    familiares = sibsp + parch
    print(f"Esta persona viajaba con {familiares} familiar(es).")
    if sibsp > 0:
        print(f"- Número de hermanos/cónyuges a bordo: {sibsp}")
    if parch > 0:
        print(f"- Número de padres/hijos a bordo: {parch}")
        
person = titanic.loc[titanic['name']=='Svensson, Mr. Johan']
person
# Out:
# Esta persona viajaba sola.
#       pclass  survived                 name   sex   age  sibsp  parch  ticket  \
# 1235       3         0  Svensson, Mr. Johan  male  74.0      0      0  347060
#
#        fare cabin embarked boat  body home.dest
# 1235  7.775   NaN        S  NaN   NaN       NaN

# %%
#titanic.loc[(titanic['age'].max() == titanic['age']) & (titanic['survived']==0)]
#muertos = titanic.loc[titanic['survived']==0]
#muertos

# %% [markdown]
# 10. Create the list of 5 random numbers of rows from 0 to the lenght of the dataframe, call it `rows`
#
# ex. `rows = [3,7,99,52,48]` use `random` library

# %%
import random

longitud = len(titanic)
rows = random.sample(range(longitud), 5)
print(rows)
# Out:
# [945, 894, 966, 405, 718]

# %% [markdown]
# This list of numbers are random, could be different.

# %% [markdown]
# 11. Create the list of three column labels, call it `cols`

# %%
cols = list(titanic.columns[:3])
print(cols)
# Out:
# ['pclass', 'survived', 'name']

# %% [markdown]
# 12. Use both lists `rows` and `cols` to create a new dataframe

# %%
df = titanic.loc[rows, cols]
df
# Out:
#      pclass  survived                                   name
# 945       3         1                           Lam, Mr. Ali
# 894       3         1        Johnson, Master. Harold Theodor
# 966       3         0  Lindahl, Miss. Agda Thorilda Viktoria
# 405       2         0              Fahlstrom, Mr. Arne Jonas
# 718       3         0         Coelho, Mr. Domingos Fernandeo

# %% [markdown]
# 13. Create a boolean array with the condition of being a woman or a man, using the `sex` column, where **female** is True. Call it `array_fe`

# %%
array_fe = titanic['sex'] == 'female'
array_fe
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 1304     True
# 1305     True
# 1306    False
# 1307    False
# 1308    False
# Name: sex, Length: 1309, dtype: bool

# %%
array_fe.head()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: sex, dtype: bool

# %% [markdown]
# 14. Rename the column `"sex"` to `"gender"` and filter the `titanic` dataframe with the boolean array, call it `woman_titanic`

# %%
cambio_nombre = titanic.rename(columns={'sex': 'gender'}, inplace=True)
array_bool = titanic['gender'] == 'female'
woman_titanic = titanic[array_bool]
woman_titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 2          1         0                     Allison, Miss. Helen Loraine
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
#
#       gender   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   gender     1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %% [markdown]
# 15. How many woman were younger than 18? Call the variable `minor_wo`

# %%
minor_wo = titanic.loc[(titanic['gender'] == 'female') & (titanic['age'] < 18)].shape[0]
minor_wo
# Out:
# 72

# %% [markdown]
# 16. How many woman that were less than 18 actually died? Call the variable `dead_wo`

# %%
dead_condition = titanic.loc[(titanic['survived']==0) & (titanic['age']<18)]
dead_wo = dead_condition.loc[dead_condition['gender']=='female']
dead_wo
# Out:
#       pclass  survived                                  name  gender   age  \
# 2          1         0          Allison, Miss. Helen Loraine  female   2.0
# 623        3         0    Andersson, Miss. Ebba Iris Alfrida  female   6.0
# 624        3         0     Andersson, Miss. Ellis Anna Maria  female   2.0
# 627        3         0  Andersson, Miss. Ingeborg Constanzia  female   9.0
# 628        3         0     Andersson, Miss. Sigrid Elisabeth  female  11.0
# 650        3         0                 Attalah, Miss. Malake  female  17.0
# 679        3         0               Boulos, Miss. Nourelain  female   9.0
# 807        3         0      Ford, Miss. Robina Maggie "Ruby"  female   9.0
# 828        3         0           Goodwin, Miss. Jessie Allis  female  10.0
# 829        3         0            Goodwin, Miss. Lillian Amy  female  16.0
# 841        3         0                  Hagardon, Miss. Kate  female  17.0
# ...

# %% [markdown]
# 17. Drop rows with *Nan* in `titanic` with `how='any'` and print the shape

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   gender     1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
titanic_sin_NaN = titanic.dropna(axis=1 ,how='any')
titanic_sin_NaN.shape
# Out:
# (1309, 7)

# %%
titanic_sin_NaN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   gender     1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %% [markdown]
# 18. Drop rows with *Nan* in `titanic` with `how='all'` and print the shape

# %%
titanic_sin_NaN = titanic.dropna(how='all')
titanic_sin_NaN.shape
# Out:
# (1309, 14)

# %% [markdown]
# Check in [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html) why the shapes are different.

# %% [markdown]
# 19. Drop columns in `titanic` with more than 1000 missing values and print the columns remaining

# %%
valores_faltantes = titanic.isnull().sum()
columnas_a_eliminar = valores_faltantes[valores_faltantes > 1000].index
titanic_cleaned = titanic.drop(columns=columnas_a_eliminar,inplace=True)
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#       gender    age  sibsp  parch  ticket      fare embarked boat  \
# ...

# %%
#titanic.dropna(axis=1,thresh=309).info()

# %% [markdown]
# 20. Calculate the ratio of missing values at the `boat` column.

# %%
#Calculamos el numero total de filas
total_filas = titanic.shape[0]

#Calculamos los valores NaN de la columna barco
missing_boat = titanic['boat'].isnull().sum()

# Calculamos el ratio
ratio = missing_boat / total_filas


print(f"El ratio de elementos NaN en la columna barco es : {ratio:.4f}")
# Out:
# El ratio de elementos NaN en la columna barco es : 0.6287

# %% [markdown]
# 21.  Group `titanic` by `'pclass'` and aggregate by the columns `age` & `fare`, by `max` and `median` and assign it to `by_class`

# %%
by_class = titanic.groupby('pclass').agg({'age': ['max', 'median'],'fare': ['max', 'median']})
by_class
# Out:
#          age             fare
#          max median       max   median
# pclass
# 1       80.0   39.0  512.3292  60.0000
# 2       70.0   29.0   73.5000  15.0458
# 3       74.0   24.0   69.5500   8.0500

# %% [markdown]
# 22. Print the maximum age in each class from `by_class`

# %%
resultado = by_class['age']['max']
resultado
# Out:
# pclass
# 1    80.0
# 2    70.0
# 3    74.0
# Name: max, dtype: float64

# %% [markdown]
# 23. Print the median fare in each class from `by_class`

# %%
resultado = by_class['fare']['median']
resultado
# Out:
# pclass
# 1    60.0000
# 2    15.0458
# 3     8.0500
# Name: median, dtype: float64

# %% [markdown]
# 24. Using [`.pivot_table()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html) to count how many women or men survived by class, call it `counted`.
#
# Don't panic and read the documentation!

# %%
counted = pd.pivot_table(titanic, values='survived', index=['gender'], columns=['pclass'], aggfunc='sum',fill_value=0)
counted
# Out:
# pclass    1   2    3
# gender
# female  139  94  106
# male     61  25   75

# %% [markdown]
# 25. Add a new column with the sum of survived men and women, call it `counted['total']`

# %%
counted['total'] = counted.sum(axis=1)
counted
# Out:
# pclass    1   2    3  total
# gender
# female  139  94  106    339
# male     61  25   75    161

# %% [markdown]
# 26. Sort `counted` by the `'total'` column. In which class the people survived the most?

# %%
total_por_clase = counted.sum()
clase_con_mas_sobrevivientes = total_por_clase.iloc[:-1].idxmax()
max_sobrevivientes = total_por_clase.iloc[:-1].max()

print(f"La clase con más sobrevivientes es la clase: {clase_con_mas_sobrevivientes}")
print(f"Número total de sobrevivientes en esta clase: {max_sobrevivientes}")
# Out:
# La clase con más sobrevivientes es la clase: 1
# Número total de sobrevivientes en esta clase: 200

# %% [markdown]
# 27. Please, show only the rows using a mask with the following conditions:
#     - They are woman
#     - From third class
#     - Younger than 30
#     - They survived
#
#     ¿How many rows fulfill the condition?

# %%
resultado1 = titanic[titanic['gender']=='female']
resultado2 = resultado1[resultado1['pclass']==3]
resultado3 = resultado2[resultado2['age']<=30]
resultado4 = resultado3[resultado3['survived']==1]
resultado4
# Out:
#       pclass  survived                                               name  \
# 604        3         1                        Abelseth, Miss. Karen Marie
# 607        3         1          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 612        3         1                         Aks, Mrs. Sam (Leah Rosen)
# 621        3         1    Andersen-Jensen, Miss. Carla Christine Nielsine
# 625        3         1                    Andersson, Miss. Erna Alexandra
# 643        3         1                     Asplund, Miss. Lillian Gertrud
# 653        3         1                               Ayoub, Miss. Banoura
# 657        3         1                             Baclini, Miss. Eugenie
# 658        3         1                      Baclini, Miss. Helene Barbara
# 659        3         1                     Baclini, Miss. Marie Catherine
# 660        3         1              Baclini, Mrs. Solomon (Latifa Qurban)
# 661        3         1                         Badman, Miss. Emily Louisa
# ...

# %% [markdown]
# 28. Now, show only the rows using `.loc` with the following conditions:
#     - They are man
#     - From first class
#     - Older than 50
#     - They died
#
#     ¿How many rows fulfill the condition?

# %%
resultado = titanic.loc[(titanic['gender']=='male') & (titanic['pclass']==1) & (titanic['age']>=50) & (titanic['survived']==0)]
resultado
# Out:
#      pclass  survived                            name gender   age  sibsp  \
# 9         1         0         Artagaveytia, Mr. Ramon   male  71.0      0
# 81        1         0    Crosby, Capt. Edward Gifford   male  70.0      1
# 96        1         0      Douglas, Mr. Walter Donald   male  50.0      1
# 115       1         0               Fortune, Mr. Mark   male  64.0      1
# 135       1         0       Goldschmidt, Mr. George B   male  71.0      0
# 154       1         0      Hays, Mr. Charles Melville   male  55.0      1
# 158       1         0     Hipkins, Mr. William Edward   male  55.0      0
# 172       1         0        Julian, Mr. Henry Forbes   male  50.0      0
# 174       1         0         Kent, Mr. Edward Austin   male  58.0      0
# 201       1         0         McCarthy, Mr. Timothy J   male  54.0      0
# 205       1         0       Millet, Mr. Francis Davis   male  65.0      0
# 210       1         0      Molson, Mr. Harry Markland   male  55.0      0
# ...

# %% [markdown]
# 29. Print the uniques values at the column `'name'`

# %%
resultado = titanic['name'].unique
resultado
# Out:
# <bound method Series.unique of 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object>

# %% [markdown]
# 30. Find if was there any `name` repeated at the Titanic?
#
# Hint: There were two people with the same name, who?

# %%
# Contamos cuántas veces aparece cada nombre
nombre_conteo = titanic['name'].value_counts()
# Filtramos los nombres que aparecen más de una vez
nombres_repetidos = nombre_conteo[nombre_conteo > 1]
nombres_repetidos
# Out:
# name
# Connolly, Miss. Kate    2
# Kelly, Mr. James        2
# Name: count, dtype: int64

# %% [markdown]
# 31. Using `matplotlib` find the appropriate visualization to show the distribution of the column `'age'`

# %%
import matplotlib.pyplot as plt

# Creamos un histograma
plt.figure(figsize=(10, 6))
plt.hist(titanic['age'].dropna(), bins=30, edgecolor='black')

# Añadimos títulos y etiquetas
plt.title('Distribución de Edades en el Titanic')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')

# Mostramos el gráfico
plt.show()

# %% [markdown]
# 32. Using `matplotlib` find the appropriate plot to visualize the column `'gender'`

# %%
import matplotlib.pyplot as plt

# Contamos la frecuencia de cada género
gender_counts = titanic['gender'].value_counts()

# Creamos un gráfico de barras
plt.figure(figsize=(8, 6))
gender_counts.plot(kind='bar', color=['blue', 'pink'])

# Añadir títulos y etiquetas
plt.title('Distribución de Géneros en el Titanic')
plt.xlabel('Género')
plt.ylabel('Número de Pasajeros')

# Añadimos etiquetas de valor en las barras
for i, v in enumerate(gender_counts):
    plt.text(i, v, str(v), ha='center', va='bottom')

# Ajustamos los márgenes
plt.tight_layout()

# Mostramos el gráfico
plt.show()

# %% [markdown]
# 32b. What if you also plot the column `'gender'` using the function [`countplot`](https://seaborn.pydata.org/generated/seaborn.countplot.html) from the library [`seaborn`](https://seaborn.pydata.org/)?
#
# Remember you have never used `seaborn` before, therefore you should install it before importing it.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Creamos el gráfico de conteo
plt.figure(figsize=(8, 6))
sns.countplot(data=titanic, x='gender',palette=['pink','blue'])

# Añadimos títulos y etiquetas
plt.title('Distribución de Géneros en el Titanic')
plt.xlabel('Género')
plt.ylabel('Número de Pasajeros')

# Añadimos etiquetas de valor en las barras
for i in plt.gca().containers:
    plt.gca().bar_label(i)

# Ajustamos los márgenes
plt.tight_layout()

# Mostramos el gráfico
plt.show()
# Out:
# C:\Users\jonam\AppData\Local\Temp\ipykernel_4752\3467052327.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=titanic, x='gender',palette=['pink','blue'])

# %% [markdown]
# 33. Using the function [`catplot`](https://seaborn.pydata.org/generated/seaborn.catplot.html) from the library `seaborn`, find out if the hypothesis _"Women are more likely to survive shipwrecks"_ is true or not.
#
# You should get something like this:

# %% [markdown]
# ![catplot](./img/catplotgen.png)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Creamos el gráfico
plt.figure(figsize=(10, 6))
sns.catplot(
    data=titanic, 
    x="gender", 
    y="survived", 
    kind="bar",
    height=6, 
    aspect=1.5
)

# Personalizamos el gráfico
plt.title("Tasa de Supervivencia por Género en el Titanic")
plt.xlabel("Género")
plt.ylabel("Tasa de Supervivencia")

# Mostramos el gráfico
plt.show()

# %% [markdown]
# 34. Using [`kdeplot`]("https://seaborn.pydata.org/generated/seaborn.kdeplot.html") from `seaborn` represent those who not survived distributed by age.<>
#
# Hint: First you should "filter" the `titanic` dataset where the column "survived" is 0, indexing the column `"age"` only.
#
# Arguments you should pass to the function:
#
#     - color = "red"
#     - label = "Not Survived"
#     - shade = True
#
# You should get something like this:

# %% [markdown]
# ![kdeplot](./img/kdeplotsur.png)

# %%
import seaborn as sns
import matplotlib.pyplot as plt


edades_no_sobrevivieron = titanic.loc[titanic['survived'] == 0,'age']
plt.figure(figsize=(10, 6))
sns.kdeplot(data=edades_no_sobrevivieron, color="red", label="Not Survived", shade=True)
plt.title("Distribución de Edad de los No Sobrevivientes del Titanic")
plt.xlabel("Edad")
plt.ylabel("Densidad")
plt.legend()
plt.show()
# Out:
# C:\Users\jonam\AppData\Local\Temp\ipykernel_4752\290349423.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=edades_no_sobrevivieron, color="red", label="Not Survived", shade=True)
